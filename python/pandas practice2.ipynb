# %%
import numpy as np
import pandas as pd

# %%
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
s=pd.Series(arr)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
random=np.random.randint(low=0,high=10,size=10)
name=np.random.choice(['a','b','c','d','e','f','g'],size=10)
choice=np.random.choice([1,2,3,4,5,6,7,8],size=10)

dict1={
    'Random':random,
    'Name':name,
    'choice':choice
}
df=pd.DataFrame(dict1)
df
# Out:
#    Random Name  choice
# 0       4    e       1
# 1       6    d       3
# 2       7    a       4
# 3       7    a       8
# 4       3    c       5
# 5       7    f       1
# 6       8    a       3
# 7       6    g       2
# 8       8    f       7
# 9       1    d       1

# %%
df.iloc[0,0]
# Out:
# 4

# %%
df.iloc[:2,:2]
# Out:
#    Random Name
# 0       4    e
# 1       6    d

# %%
loc_df=pd.read_csv('Downloads\Sample100.csv')
loc_df
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
loc_df.set_index('Serial Number',inplace=True)

# %%
loc_df
# Out:
#                                 Company Name  Employee Markme  \
# Serial Number
# 9788189999599                 TALES OF SHIVA             Mark
# 9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 9780198082897                       MY KUMAN             Mark
# 9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 9780545060455               THE BLACK CIRCLE             Mark
# ...                                      ...              ...
# 9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 9788184821543           MORE TALES OF BIRBAL                -
# 9788184821550         TALES FROM THE JATAKAS                -
# 9788184821567               RAMarkS OF MEWAR                -
# 9788184821574       THE SONS OF THE PANDAVAS                -
#
#                       Description  Leave
# Serial Number
# 9788189999599                mark      0
# 9780099578079                Mark      0
# 9780198082897                Mark      0
# ...

# %%
loc_df.loc["TALES OF SHIVA"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'TALES OF SHIVA'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-eaf9e8d70d55> in <module>
# ----> 1 loc_df.loc["TALES OF SHIVA"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
# ...

# %%
dict1={
    'Letter':['a','b','c','d'],
    'Number':[1,2,3,4]
}
df=pd.DataFrame(dict1)
df
# Out:
#   Letter  Number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4

# %%
dict2={
    'Letter':['c','d','e','f'],
    'Number':[3,4,5,6]
}
df1=pd.DataFrame(dict2)
df1
# Out:
#   Letter  Number
# 0      c       3
# 1      d       4
# 2      e       5
# 3      f       6

# %%
pd.concat([df,df1],axis=0)
# Out:
#   Letter  Number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4
# 0      c       3
# 1      d       4
# 2      e       5
# 3      f       6

# %%
pd.concat([df,df1],axis=0,ignore_index=True)
# Out:
#   Letter  Number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4
# 4      c       3
# 5      d       4
# 6      e       5
# 7      f       6

# %%
pd.concat([df,df1],axis=1)
# Out:
#   Letter  Number Letter  Number
# 0      a       1      c       3
# 1      b       2      d       4
# 2      c       3      e       5
# 3      d       4      f       6

# %%
dict1={
    'city':['a','b','c','d'],
    'tempeerature':[20,21,22,33]
}
df=pd.DataFrame(dict1)
df
# Out:
#   city  tempeerature
# 0    a            20
# 1    b            21
# 2    c            22
# 3    d            33

# %%
dict2={
    'city':['c','d','e','f'],
    'temperature':[30,31,32,33]
}
df1=pd.DataFrame(dict2)
df1
# Out:
#   city  temperature
# 0    c           30
# 1    d           31
# 2    e           32
# 3    f           33

# %%
df2=pd.merge(df,df1,on='city')
df2
# Out:
#   city  tempeerature  temperature
# 0    c            22           30
# 1    d            33           31

# %%
df3=pd.merge(df,df1,how='outer')
df3
# Out:
#   city  tempeerature  temperature
# 0    a          20.0          NaN
# 1    b          21.0          NaN
# 2    c          22.0         30.0
# 3    d          33.0         31.0
# 4    e           NaN         32.0
# 5    f           NaN         33.0

# %%
data = pd.Series([0, 1, 2, 3, 4, 5,np.nan, 6, 7, 8])
data
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    4.0
# 5    5.0
# 6    NaN
# 7    6.0
# 8    7.0
# 9    8.0
# dtype: float64

# %%
data.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
dict1 = {
    0:[1,4,7,np.nan],
    1:[2,5,np.nan,np.nan],
    2:[3,np.nan,np.nan,np.nan],
    3:[np.nan,np.nan,np.nan,np.nan]
}
df=pd.DataFrame(dict1)
df
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0 NaN
# 1  4.0  5.0  NaN NaN
# 2  7.0  NaN  NaN NaN
# 3  NaN  NaN  NaN NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
df.dropna(how='all')
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0 NaN
# 1  4.0  5.0  NaN NaN
# 2  7.0  NaN  NaN NaN

# %%
loc_df1=pd.read_csv('SampleCSVFile_2kb(1)')
loc_df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-b3e499457771> in <module>
# ----> 1 loc_df1=pd.read_csv('SampleCSVFile_2kb(1)')
#       2 loc_df1
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...
